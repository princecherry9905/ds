# %% [markdown]
# <a href="https://colab.research.google.com/github/princecherry9905/ds/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **pandas**

# %%
import pandas as pd
dct ={
    'name':['tom','nick','krish','jack'],
    'age':[20,21,19,18 ],
    'roll':[1,2,3,4]
}
df = pd.DataFrame(dct)
#print(df)
df
display(df)
# Out:
#     name  age  roll
# 0    tom   20     1
# 1   nick   21     2
# 2  krish   19     3
# 3   jack   18     4

# %%
df = pd.read_csv('./student_data.csv')
df.head(3)
df.tail(5)

#df.shape
#df.info()
#df.describe()
#df.columns
#df.index
#df[['study hours','internet_usage']]
#df.iloc[0]
#df.iloc[0:5]
#df.loc[df['study_hours'] ==11].iloc[4:8]
#df.loc[df['assignments_completed'] ==8].iloc[1]
#df[df["assignments_completed"]>3]
#rename columns
#df.rename(columns={'assignments_completed':'assign_completed'},inplace=True)
#df
#df.drop('study_hours',axis=1)
dct={
    'name':['tom','nick','krish','jack'],
    'age':[20,21,19,18 ],
    'roll':[1,0,3,None]
}
df.sort_values('study_hours')
df.sort_index()
df.isnull()
df.notnull()
df.fillna(1)
