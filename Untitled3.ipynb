# %% [markdown]
# <a href="https://colab.research.google.com/github/princecherry9905/ds/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

df1= pd.DataFrame({
    'id':[1,2,3,4],
    'name':['raja','rani','rahul','rhea'],
    'age':[25,30,35,40]
})
df2= pd.DataFrame({
    'id':[1,6,8,4],
    'name':['raja','rani','rahul','rhea'],
    'age':[35,30,75,80]
})
#df3=pd.merge(df1,df2,on='id',how='inner')#inner join
#df3.rename(columns={'name_x':'tablename1'},inplace=True)
#print(df3)
#pd.merge(df1,df2,on='id',how='left')#left join
#df3=pd.merge(df1,df2,how='cross')
#print(df3)
df3=pd.concat([df1,df2])
print(df3)
# Out:
#    id   name  age
# 0   1   raja   25
# 1   2   rani   30
# 2   3  rahul   35
# 3   4   rhea   40
# 0   1   raja   35
# 1   6   rani   30
# 2   8  rahul   75
# 3   4   rhea   80

# %%
import pandas as pd

df1= pd.DataFrame({
    'id':[1,2,3,4],
    'name':['raja','rani','rahul','rhea'],
    'age':[25,30,35,40]
})
df2= pd.DataFrame({
    'id':[1,6,8,4],
    'name':['raja','rani','rahul','rhea'],
    'age':[35,30,75,80]
})
df3=df3.drop_duplicates(subset=['id'])
print(df3)
df3=df3.drop_duplicates(subset=['id','name'],keep='first')
print(df3)
# Out:
#    id   name  age
# 0   1   raja   25
# 1   2   rani   30
# 2   3  rahul   35
# 3   4   rhea   40
# 1   6   rani   30
# 2   8  rahul   75
#    id   name  age
# 0   1   raja   25
# 1   2   rani   30
# 2   3  rahul   35
# 3   4   rhea   40
# 1   6   rani   30
# 2   8  rahul   75

# %%
import pandas as pd

df=pd.read_csv('./student_data.csv')
print(df)
df.pivot_table(columns='placement_status',index='sleep_hours',values='exam_score',aggfunc='mean')
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
import pandas as pd

df=pd.read_csv('./student_data.csv')

df.pivot_table(columns='study_hours',index='sleep_hours',values='assignments_completed',aggfunc='mean')
# Out:
# study_hours         1          2          3          4          5          6   \
# sleep_hours
# 4             9.980392  10.283784  10.166667   9.529801  10.187050  10.530612
# 5            10.231707   9.837838  10.051948   9.706667   9.679487  10.604651
# 6            10.566265  10.417808  10.229299   9.694805  10.066667  10.131737
# 7            11.026846   9.166667   9.440252  10.007143   9.888889   9.606250
# 8             9.303448   8.741935   9.807692  10.204545   9.843373  10.105960
# 9            10.245283   9.646667   9.968944   9.582822  10.308725   9.744681
#
# study_hours         7          8          9          10         11
# sleep_hours
# 4             9.836158  10.486111   9.950000   9.114458   9.662420
# 5            11.151515  10.118519  10.616279   9.886228   9.863946
# 6             9.934307  10.601399   9.868966   9.375000   9.291045
# 7            10.750000   8.380368  11.130719  10.506024   9.741007
# ...
