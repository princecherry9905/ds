# %% [markdown]
# <a href="https://colab.research.google.com/github/princecherry9905/ds/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import numpy as np

products = []
prices = []

n = int(input("Enter number of products: "))

for i in range(n):
    product = input(f"Enter name of product {i+1}: ")
    price = float(input(f"Enter price of {product}: "))

    products.append(product)
    prices.append(price)

p = np.array(prices)

print("\nProducts and Prices:")
for i in range(n):
    print(products[i], ":", prices[i])

print("\nHighest Price:", p.max())
print("Lowest Price:", p.min())
print("Total Price:", p.sum())
print("Average Price:", p.mean())
print("Standard Deviation:", p.std())

# %%
a = np.random.randint(1,90,(5,5));
print(a)
n1=np.mean(a,axis=0);
print(n1)
n2=np.mean(a,axis=1);
print(n2)
#print(sorted(n1))
#print(sorted(n2))
p1=np.sort(a,axis=0);
print(p1)
p2=np.sort(a,axis=1);
print(p2)
t1=np.sum(a,axis=0);
print(t1)
t2=np.sum(a,axis=1);
print(t2)
y=np.count_nonzero(a<0,axis=1)
print(y);
# Out:
# [[44 54 54 85 12]
#  [10 74  5 83  8]
#  [ 4 48 75 50 82]
#  [15 77  4 89 76]
#  [61 13 68 30 47]]
# [26.8 53.2 41.2 67.4 45. ]
# [49.8 36.  51.8 52.2 43.8]
# [[ 4 13  4 30  8]
#  [10 48  5 50 12]
#  [15 54 54 83 47]
#  [44 74 68 85 76]
#  [61 77 75 89 82]]
# [[12 44 54 54 85]
#  [ 5  8 10 74 83]
#  [ 4 48 50 75 82]
#  [ 4 15 76 77 89]
#  [13 30 47 61 68]]
# [134 266 206 337 225]
# [249 180 259 261 219]
# [0 0 0 0 0]

# %%
stock = np.random.randint(20,80,(5,5));
print(stock)
demand=np.random.randint(20,80,(5,5));
print(demand)
p=stock-demand
print(p)
t=np.where(p<0,0,p)
print(t)
#sort
p2=np.sort(p,axis=1);
print(p2)
#total shotage
totalShortage = np.sum(np.where(p<1,p,0),axis = 0)
print("\n",totalShortage)
# Out:
# [[23 46 30 70 34]
#  [46 45 45 55 76]
#  [27 27 51 63 73]
#  [56 28 30 50 36]
#  [42 79 76 30 45]]
# [[22 41 79 53 20]
#  [79 38 41 50 45]
#  [46 43 43 59 55]
#  [20 75 32 65 24]
#  [61 26 73 50 73]]
# [[  1   5 -49  17  14]
#  [-33   7   4   5  31]
#  [-19 -16   8   4  18]
#  [ 36 -47  -2 -15  12]
#  [-19  53   3 -20 -28]]
# [[ 1  5  0 17 14]
#  [ 0  7  4  5 31]
#  [ 0  0  8  4 18]
#  [36  0  0  0 12]
#  [ 0 53  3  0  0]]
# [[-49   1   5  14  17]
#  [-33   4   5   7  31]
#  [-19 -16   4   8  18]
#  [-47 -15  -2  12  36]
#  [-28 -20 -19   3  53]]
#
#  [-71 -63 -51 -35 -28]
